# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(columns='Ticket', inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Cabin Embarked
# 0      0   7.2500   NaN        S
# 1      0  71.2833   C85        C
# 2      0   7.9250   NaN        S
# 3      0  53.1000  C123        S
# 4      0   8.0500   NaN        S

# %%
df.drop(columns='Cabin', inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked
# 0      0   7.2500        S
# 1      0  71.2833        C
# 2      0   7.9250        S
# 3      0  53.1000        S
# 4      0   8.0500        S

# %%
df.drop(columns='PassengerId', inplace=True)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Age'] = df['Age'].astype(int)

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.544332    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.013778    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['Embarked']=df['Embarked'].fillna('S')

# %%
plt.bar(df['Sex'],df['Survived'])
# Out:
# <BarContainer object of 891 artists>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(16,12))

ax[0,0].bar(df['Sex'],df['Age'], color=['green'])



#sns.kdeplot(df['Age'])
#sns.countplot(x=df['Sex'])
# for i in range(df.shape[0]):
#     ax[0,1].text(df['Age'].values[i], df['Fare'].values[i],df['Embarked'].values[i])
# Out:
# <BarContainer object of 891 artists>

# %%
df[df['Fare']<350][['Fare']]
# Out:
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
# 890   7.7500
#
# [888 rows x 1 columns]

# %%
ss=df[df['Sex']=='male']['Survived']==1
ss.sum()
# Out:
# 109

# %%
ss=df[df['Sex']=='female']['Survived']==1
ss.sum()
# Out:
# 233

# %%
df['Survived'].sum()
# Out:
# 342

# %%
# countplot
df.sample(5)
# Out:
#      Survived  Pclass                                               Name  \
# 725         0       3                                Oreskovic, Mr. Luka
# 523         1       1    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)
# 590         0       3                               Rintamaki, Mr. Matti
# 41          0       2  Turpin, Mrs. William John Robert (Dorothy Ann ...
# 409         0       3                                 Lefebre, Miss. Ida
#
#         Sex  Age  SibSp  Parch     Fare Embarked
# 725    male   20      0      0   8.6625        S
# 523  female   44      0      1  57.9792        C
# 590    male   35      0      0   7.1250        S
# 41   female   27      1      0  21.0000        S
# 409  female   29      3      1  25.4667        S

# %%
df.drop(columns=['Name','Parch'], inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex  Age  SibSp     Fare Embarked
# 0         0       3    male   22      1   7.2500        S
# 1         1       1  female   38      1  71.2833        C
# 2         1       3  female   26      0   7.9250        S
# 3         1       1  female   35      1  53.1000        S
# 4         0       3    male   35      0   8.0500        S

# %%
df.shape
# Out:
# (891, 7)

# %% [markdown]
# ### Countplot

# %% [markdown]
# # 1.) most of the traverlers are male or female

# %%
# 1.) most of the traverlers are male or female


# df['Sex'].value_counts().plot(kind='bar')
sns.countplot(x=df['Sex'])
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2.) Survival rate

# %%
sns.countplot(x=df['Survived'])
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
plt.pie(df['Survived'].value_counts(),labels=df['Survived'].unique(), autopct='%.2f%%', explode=[0, 0.04], shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2bc1b289e10>,
# ...
#  [Text(-0.3925749350994583, 1.0275626113924428, '0'),
#   Text(0.40685048699069565, -1.064928486441899, '1')],
#  [Text(-0.21413178278152267, 0.5604886971231505, '61.62%'),
#   Text(0.2284072909421449, -0.5978545888796626, '38.38%')])

# %% [markdown]
# # 3.) in which classs most of the traverlers are traveling

# %%
sns.countplot(x=df['Pclass'])
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # 4.) traverlers ages

# %%
#sns.displot(df['Age'])
#sns.kdeplot(df['Age'])

plt.hist(df['Age'])
# Out:
# (array([ 50.,  33., 164., 358., 123.,  74.,  50.,  26.,  11.,   2.]),
#  array([ 0.,  8., 16., 24., 32., 40., 48., 56., 64., 72., 80.]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(df['Age'], shade=True)
# Out:
# C:\Users\shani\AppData\Local\Temp\ipykernel_23076\2438558368.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Age'], shade=True)
# c:\Users\shani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(df['Age'], rug=True, kde=True)
# Out:
# c:\Users\shani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.hist(df['Age'])
# Out:
# (array([ 50.,  33., 164., 358., 123.,  74.,  50.,  26.,  11.,   2.]),
#  array([ 0.,  8., 16., 24., 32., 40., 48., 56., 64., 72., 80.]),
#  <BarContainer object of 10 artists>)

# %%
df.groupby('Survived')['Sex'].value_counts()
# Out:
# Survived  Sex
# 0         male      468
#           female     81
# 1         female    233
#           male      109
# Name: count, dtype: int64

# %% [markdown]
# # 5.) Mean fare values

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df.groupby('Pclass')['Fare'].max()
# Out:
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
df.groupby('Pclass')['Fare'].min()
# Out:
# Pclass
# 1    0.0
# 2    0.0
# 3    0.0
# Name: Fare, dtype: float64

# %%
df.groupby('Pclass')['Fare'].describe()
# Out:
#         count       mean        std  min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
df[(df['Fare']<500) & (df['Fare']>200)]
# Out:
#      Survived  Pclass     Sex  Age  SibSp      Fare Embarked
# 27          0       1    male   19      3  263.0000        S
# 88          1       1  female   23      3  263.0000        S
# 118         0       1    male   24      0  247.5208        C
# 299         1       1  female   50      0  247.5208        C
# 311         1       1  female   18      2  262.3750        C
# 341         1       1  female   24      3  263.0000        S
# 377         0       1    male   27      0  211.5000        C
# 380         1       1  female   42      0  227.5250        C
# 438         0       1    male   64      1  263.0000        S
# 527         0       1    male   29      0  221.7792        S
# 557         0       1    male   29      0  227.5250        C
# 689         1       1  female   15      0  211.3375        S
# 700         1       1  female   18      1  227.5250        C
# 716         1       1  female   38      0  227.5250        C
# ...

# %%
df[df['Fare']==0]
# Out:
#      Survived  Pclass   Sex  Age  SibSp  Fare Embarked
# 179         0       3  male   36      0   0.0        S
# 263         0       1  male   40      0   0.0        S
# 271         1       3  male   25      0   0.0        S
# 277         0       2  male   29      0   0.0        S
# 302         0       3  male   19      0   0.0        S
# 413         0       2  male   29      0   0.0        S
# 466         0       2  male   29      0   0.0        S
# 481         0       2  male   29      0   0.0        S
# 597         0       3  male   49      0   0.0        S
# 633         0       1  male   29      0   0.0        S
# 674         0       2  male   29      0   0.0        S
# 732         0       2  male   29      0   0.0        S
# 806         0       1  male   39      0   0.0        S
# 815         0       1  male   29      0   0.0        S
# 822         0       1  male   38      0   0.0        S

# %%
new = df[df['Fare']<350]
new[new['Pclass']==1]
# Out:
#      Survived  Pclass     Sex  Age  SibSp     Fare Embarked
# 1           1       1  female   38      1  71.2833        C
# 3           1       1  female   35      1  53.1000        S
# 6           0       1    male   54      0  51.8625        S
# 11          1       1  female   58      0  26.5500        S
# 23          1       1    male   28      0  35.5000        S
# ..        ...     ...     ...  ...    ...      ...      ...
# 871         1       1  female   47      1  52.5542        S
# 872         0       1    male   33      0   5.0000        S
# 879         1       1  female   56      0  83.1583        C
# 887         1       1  female   19      0  30.0000        S
# 889         1       1    male   26      0  30.0000        C
#
# [213 rows x 7 columns]

# %%
sns.boxplot(new[new['Pclass']==3])
# Out:
# <Axes: >

# %% [markdown]
# # Bivariate and multivariate analysis

# %%
df=sns.load_dataset('tips')

# %%
flights=sns.load_dataset('flights')

# %%
iris=sns.load_dataset('iris')

# %%
iris['species']=iris['species'].replace({'setosa':0,'versicolor':1,'virginica':2})

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# # 1. Scatter plot  ( Numerical - Numerical )

# %%
plt.scatter(df['total_bill'],df['tip'],s=df['tip']*5, c=df['tip'])
plt.colorbar()

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'], hue=df['sex'], style=df['smoker'],size=df['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2. Barplot ( numerical - categorical )

# %%
sns.barplot(x=df['Pclass'],y=df['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
plt.bar(df['Pclass'],df['Age'])
# Out:
# <BarContainer object of 891 artists>

# %%
sns.barplot(x=df['Pclass'],y=df['Fare'], hue=df['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x=df['Pclass'],y=df['Age'], hue=df['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # 4.) boxplot (Numerical - categorical)

# %%
sns.boxplot(x=df['Sex'],y=df['Age'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=df['Sex'],y=df['Age'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # 3.) kdeplot or distplot (numerical - categorical)

# %%
df_1 = df[df['Survived']==1]['Age']
df_0 = df[df['Survived']==0]['Age']


sns.kdeplot(df_1, color='orange')
sns.kdeplot(df_0)
# Out:
# c:\Users\shani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\shani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # 6.) Heatmap (Categorical - Categorical)

# %%
pd.crosstab(df['Pclass'],df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.clustermap(pd.crosstab(df['Pclass'],df['Survived']))

# %%
df.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
df.groupby('Embarked')['Survived'].mean()*100
# Out:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.900929
# Name: Survived, dtype: float64

# %%
df.groupby('Sex')['Embarked'].value_counts()
# Out:
# Sex     Embarked
# female  S           205
#         C            73
#         Q            36
# male    S           441
#         C            95
#         Q            41
# Name: count, dtype: int64

# %%
df.groupby('Survived')['Age'].mean()
# Out:
# Survived
# 0    30.240437
# 1    28.426901
# Name: Age, dtype: float64

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
new = flights.groupby('year')['passengers'].sum().reset_index()

# %%
plt.plot(new['year'],new['passengers'])

# %%
sns.lineplot(x=new['year'],y=new['passengers'])
# Out:
# c:\Users\shani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\shani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='passengers'>
